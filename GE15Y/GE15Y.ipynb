# %%
import pandas as pd

# %% [markdown]
# #### Install openpyxl Library to read the excel file.

# %%
# !pip3 install openpyxl

# %% [markdown]
# ## Data Processing

# %%
df_raw = pd.read_excel('GE15Y.xlsx').drop(index=0) # Read data file

# %% [markdown]
# ### Check the number of rows and columns in data file

# %%
df_raw.shape # There are 8785 rows and 24 columns
# Out:
# (8785, 24)

# %% [markdown]
# ### Check Missing values

# %%
df_raw.drop(index=8785)
# Out:
#                      Date                 Time   Rg Ratm Rn T_soilref    Ta  \
# 1     2012-01-01 00:00:00             00:00:00  NaN  NaN  0       NaN  11.9
# 2     2012-01-01 01:00:00             01:00:00  NaN  NaN  0       NaN  11.7
# 3     2012-01-01 02:00:00             02:00:00  NaN  NaN  0       NaN  11.8
# 4     2012-01-01 03:00:00             03:00:00  NaN  NaN  0       NaN  11.7
# 5     2012-01-01 04:00:00             04:00:00  NaN  NaN  0       NaN  11.8
# ...                   ...                  ...  ...  ... ..       ...   ...
# 8780  2012-12-31 19:00:00  1900-12-30 19:00:00  NaN  NaN  0       NaN     9
# 8781  2012-12-31 20:00:00  1900-12-30 20:00:00  NaN  NaN  0       NaN   8.8
# 8782  2012-12-31 21:00:00  1900-12-30 21:00:00  NaN  NaN  0       NaN     8
# 8783  2012-12-31 22:00:00  1900-12-30 22:00:00  NaN  NaN  0       NaN   7.4
# 8784  2012-12-31 23:00:00  1900-12-30 23:00:00  NaN  NaN  0       NaN   7.2
#
# ...

# %%
df_raw.isna().sum()
# Out:
# Date                         1
# Time                         1
# Rg                        8785
# Ratm                      8785
# Rn                         544
# T_soilref                 4630
# Ta                           1
# RH                           1
# uref                         1
# LAI_total                 8785
# LAI_green                 8785
# displacement_height       8785
# z0_soil                   8785
# z0_canopy                 8785
# zh                        8785
# zref                      8785
# Rain                         1
# O3_concentration             0
# Pesticid_concentration       0
# Pest_soil                    0
# NH3_concentration            0
# GammaLeaf_NH3                0
# GammaSoil_NH3                0
# R_litter_NH3                 0
# dtype: int64

# %%
df = df_raw.fillna(0)
df
# Out:
# /var/folders/dq/43_5rtyn5lz1p4vkq89ykdw40000gn/T/ipykernel_60957/1462793429.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df_raw.fillna(0)
#                      Date                 Time  Rg  Ratm   Rn  T_soilref  \
# 1     2012-01-01 00:00:00             00:00:00   0     0  0.0        0.0
# 2     2012-01-01 01:00:00             01:00:00   0     0  0.0        0.0
# 3     2012-01-01 02:00:00             02:00:00   0     0  0.0        0.0
# 4     2012-01-01 03:00:00             03:00:00   0     0  0.0        0.0
# 5     2012-01-01 04:00:00             04:00:00   0     0  0.0        0.0
# ...                   ...                  ...  ..   ...  ...        ...
# 8781  2012-12-31 20:00:00  1900-12-30 20:00:00   0     0  0.0        0.0
# ...

# %%
df.isna().sum()
# Out:
# Date                      0
# Time                      0
# Rg                        0
# Ratm                      0
# Rn                        0
# T_soilref                 0
# Ta                        0
# RH                        0
# uref                      0
# LAI_total                 0
# LAI_green                 0
# displacement_height       0
# z0_soil                   0
# z0_canopy                 0
# zh                        0
# zref                      0
# Rain                      0
# O3_concentration          0
# Pesticid_concentration    0
# Pest_soil                 0
# NH3_concentration         0
# GammaLeaf_NH3             0
# GammaSoil_NH3             0
# R_litter_NH3              0
# dtype: int64
