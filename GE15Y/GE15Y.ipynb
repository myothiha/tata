# %%
import pandas as pd

# %% [markdown]
# #### Install openpyxl Library to read the excel file.

# %%
# !pip3 install openpyxl

# %% [markdown]
# ## Data Processing

# %%
GE15Y_raw = pd.read_excel('GE15Y.xlsx').drop(index=0) # Read data file

# %% [markdown]
# ### Check the number of rows and columns in data file

# %%
GE15Y_raw.shape # There are 8785 rows and 24 columns
# Out:
# (8785, 24)

# %% [markdown]
# ### Check Missing values

# %%
GE15Y_raw = GE15Y_raw.drop(index=8785)

# %%
GE15Y_raw.isna().sum()
# Out:
# Date                         0
# Time                         0
# Rg                        8784
# Ratm                      8784
# Rn                         543
# T_soilref                 4629
# Ta                           0
# RH                           0
# uref                         0
# LAI_total                 8784
# LAI_green                 8784
# displacement_height       8784
# z0_soil                   8784
# z0_canopy                 8784
# zh                        8784
# zref                      8784
# Rain                         0
# O3_concentration             0
# Pesticid_concentration       0
# Pest_soil                    0
# NH3_concentration            0
# GammaLeaf_NH3                0
# GammaSoil_NH3                0
# R_litter_NH3                 0
# dtype: int64

# %%
GE15Y = GE15Y_raw.fillna(0)
GE15Y
# Out:
# /var/folders/dq/43_5rtyn5lz1p4vkq89ykdw40000gn/T/ipykernel_14107/3591906512.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   GE15Y = GE15Y_raw.fillna(0)
#                     Date                 Time  Rg  Ratm   Rn  T_soilref    Ta  \
# 1    2012-01-01 00:00:00             00:00:00   0     0  0.0        0.0  11.9
# 2    2012-01-01 01:00:00             01:00:00   0     0  0.0        0.0  11.7
# 3    2012-01-01 02:00:00             02:00:00   0     0  0.0        0.0  11.8
# 4    2012-01-01 03:00:00             03:00:00   0     0  0.0        0.0  11.7
# 5    2012-01-01 04:00:00             04:00:00   0     0  0.0        0.0  11.8
# ...                  ...                  ...  ..   ...  ...        ...   ...
# ...

# %%
GE15Y.isna().sum()
# Out:
# Date                      0
# Time                      0
# Rg                        0
# Ratm                      0
# Rn                        0
# T_soilref                 0
# Ta                        0
# RH                        0
# uref                      0
# LAI_total                 0
# LAI_green                 0
# displacement_height       0
# z0_soil                   0
# z0_canopy                 0
# zh                        0
# zref                      0
# Rain                      0
# O3_concentration          0
# Pesticid_concentration    0
# Pest_soil                 0
# NH3_concentration         0
# GammaLeaf_NH3             0
# GammaSoil_NH3             0
# R_litter_NH3              0
# dtype: int64

# %% [markdown]
# ## Read Another CSV File with SWC data

# %%
SWC_raw = pd.read_csv('GE15Y_SWC.csv').drop(index=0)
SWC_raw
# Out:
#             Date      Time   Rg Ratm Rn T_soilref    Ta  RH uref LAI_total  \
# 1       1/1/2012   0:00:00  NaN  NaN  0       NaN  11.9  93  4.9       NaN
# 2       1/1/2012   1:00:00  NaN  NaN  0       NaN  11.7  95  4.3       NaN
# 3       1/1/2012   2:00:00  NaN  NaN  0       NaN  11.8  94  3.7       NaN
# 4       1/1/2012   3:00:00  NaN  NaN  0       NaN  11.7  96  3.5       NaN
# 5       1/1/2012   4:00:00  NaN  NaN  0       NaN  11.8  95  4.2       NaN
# ...          ...       ...  ...  ... ..       ...   ...  ..  ...       ...
# 8780  12/31/2012  19:00:00  NaN  NaN  0       NaN     9  78  6.3       NaN
# 8781  12/31/2012  20:00:00  NaN  NaN  0       NaN   8.8  77  6.6       NaN
# 8782  12/31/2012  21:00:00  NaN  NaN  0       NaN     8  84    6       NaN
# 8783  12/31/2012  22:00:00  NaN  NaN  0       NaN   7.4  91  5.1       NaN
# 8784  12/31/2012  23:00:00  NaN  NaN  0       NaN   7.2  94  5.3       NaN
#
# ...

# %%
SWC_raw.shape
# Out:
# (8784, 25)

# %%
SWC_raw.columns
# Out:
# Index(['Date', 'Time', 'Rg', 'Ratm', 'Rn', 'T_soilref', 'Ta', 'RH', 'uref',
#        'LAI_total', 'LAI_green', 'displacement_height', 'z0_soil', 'z0_canopy',
#        'zh', 'zref', 'Rain', 'O3_concentration', 'Pesticid_concentration',
#        'Pest_soil', 'NH3_concentration', 'GammaLeaf_NH3', 'GammaSoil_NH3',
#        'R_litter_NH3', 'SWC'],
#       dtype='object')

# %%
SWC_raw.isna().sum()
# Out:
# Date                         0
# Time                         0
# Rg                        8784
# Ratm                      8784
# Rn                         543
# T_soilref                 4629
# Ta                           0
# RH                           0
# uref                         0
# LAI_total                 8784
# LAI_green                 8784
# displacement_height       8784
# z0_soil                   8784
# z0_canopy                 8784
# zh                        8784
# zref                      8784
# Rain                         0
# O3_concentration             0
# Pesticid_concentration       0
# Pest_soil                    0
# NH3_concentration            0
# GammaLeaf_NH3                0
# GammaSoil_NH3                0
# R_litter_NH3                 0
# SWC                       1710
# dtype: int64

# %%
SWC = SWC_raw.fillna(0)
SWC.head()
# Out:
# /var/folders/dq/43_5rtyn5lz1p4vkq89ykdw40000gn/T/ipykernel_14107/2351469387.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   SWC = SWC_raw.fillna(0)
#        Date     Time  Rg  Ratm Rn T_soilref    Ta  RH uref  LAI_total  ...  \
# 1  1/1/2012  0:00:00   0     0  0         0  11.9  93  4.9          0  ...
# 2  1/1/2012  1:00:00   0     0  0         0  11.7  95  4.3          0  ...
# 3  1/1/2012  2:00:00   0     0  0         0  11.8  94  3.7          0  ...
# 4  1/1/2012  3:00:00   0     0  0         0  11.7  96  3.5          0  ...
# 5  1/1/2012  4:00:00   0     0  0         0  11.8  95  4.2          0  ...
#
#    zref  Rain  O3_concentration  Pesticid_concentration  Pest_soil  \
# 1     0     0         26.986734                       0          0
# ...

# %%
GE15Y['Time'] = pd.to_datetime(GE15Y['Time'].astype(str)).dt.time
# Out:
# /var/folders/dq/43_5rtyn5lz1p4vkq89ykdw40000gn/T/ipykernel_14107/1898071005.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   GE15Y['Time'] = pd.to_datetime(GE15Y['Time'].astype(str)).dt.time

# %%
GE15Y['datetime'] = pd.to_datetime(GE15Y['Date'].astype(str) + " " + GE15Y['Time'].astype(str))
# Out:
# /var/folders/dq/43_5rtyn5lz1p4vkq89ykdw40000gn/T/ipykernel_14107/1710329710.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   GE15Y['datetime'] = pd.to_datetime(GE15Y['Date'].astype(str) + " " + GE15Y['Time'].astype(str))

# %%
SWC['datetime'] = pd.to_datetime(SWC['Date'] + " " + SWC['Time'])
